# %%
from simulador_app import main as app

display(app.main())
# Out:
# Insira o valor Financiado: 158400
# Insira a taxa de juros: 7.4
# Insira o prazo para pagamento: 360
# Caso queira amortizar adicionalmente, insira a media mensal: 4000
#      Parcela Amortização Amortização adicional   Juros Saldo Devedor
# 1   1.416,80      440,00              4.000,00  976,80    153.960,00
# 2   1.389,42      440,00              4.000,00  949,42    149.520,00
# 3   1.362,04      440,00              4.000,00  922,04    145.080,00
# 4   1.334,66      440,00              4.000,00  894,66    140.640,00
# 5   1.307,28      440,00              4.000,00  867,28    136.200,00
# 6   1.279,90      440,00              4.000,00  839,90    131.760,00
# 7   1.252,52      440,00              4.000,00  812,52    127.320,00
# 8   1.225,14      440,00              4.000,00  785,14    122.880,00
# 9   1.197,76      440,00              4.000,00  757,76    118.440,00
# 10  1.170,38      440,00              4.000,00  730,38    114.000,00
# ...
